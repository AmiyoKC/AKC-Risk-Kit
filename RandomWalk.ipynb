# %% [markdown]
# ## Random Walk Generation

# %%
import numpy as np
import pandas as pd

def gbm(n_years=10,n_scenarios=1000,mu = 0.07, sigma = 0.15,steps_per_year=12, s_0=100.0):
    """
    Evolution of a stock price using a geomtrice Brownian motion model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+(mu*dt)),scale=sigma*np.sqrt(dt),size=(n_steps, n_scenarios))
#    rets = pd.DataFrame(rets)
    price = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return price

# %%
p = gbm(n_years=10, n_scenarios=3)
p
# Out:
#               0           1           2
# 0    102.366452   98.118958   98.128569
# 1    105.450984  106.269113   97.335751
# 2    101.877555  107.610874  103.556958
# 3    101.266630  111.468308   98.861786
# 4    102.681045  117.070693   98.056009
# ..          ...         ...         ...
# 115  269.274636  306.701070  193.714563
# 116  284.734141  279.778794  182.709259
# 117  258.461063  263.734683  192.255046
# 118  252.238035  269.860014  186.006777
# 119  264.076116  269.316516  183.450886
#
# [120 rows x 3 columns]

# %%
p.plot()

# %%
p=gbm(n_years=10,n_scenarios =1000).plot(figsize=(12,6))

# %%
def gbm0(n_years=10,n_scenarios=1000,mu = 0.07, sigma = 0.15,steps_per_year=12, s_0=100.0):
    """
    Evolution of a stock price using a geomtrice Brownian motion model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = (mu*dt) + sigma*(dt**0.5)*xi
    rets = pd.DataFrame(rets)
    price = s_0*(1+rets).cumprod()
    return price

# %%
# %timeit gbm0(n_years=5,n_scenarios=1000)
# Out:
# 7.49 ms ± 1.5 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit gbm1(n_years=5,n_scenarios=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c52435ee1d73> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', 'gbm1(n_years=5,n_scenarios=1000)')
#
# ~\.conda\envs\AmiyosTrainingEnv\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~\.conda\envs\AmiyosTrainingEnv\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
gbm(n_years=10,n_scenarios=20).plot(figsize=(12,6),legend=False)

# %%
import numpy as np
import pandas as pd

def gbm(n_years=10,n_scenarios=1000,mu = 0.07, sigma = 0.15,steps_per_year=12, s_0=100.0):
    """
    Evolution of a stock price using a geomtrice Brownian motion model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=sigma*np.sqrt(dt),size=(n_steps, n_scenarios))
    rets_plus_1[0] = 1
    #   rets = pd.DataFrame(rets)
    price = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return price

# %%
gbm(n_years=10,n_scenarios=20).head()
gbm(n_years=10,n_scenarios=20).plot(figsize=(12,6),legend=False)

# %%
import ipywidgets as widgets

# %%
def squareint(n):
    return n*n

# %%
squareint(5)

# %%
widgets.interact(squareint, n=(0,100))
